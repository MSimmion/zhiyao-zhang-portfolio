# %%
# Data
height_age10 <- c(132, 140, 137, 150, 155, 127, 147, 135, 135, 124, 127, 145)
height_age16 <- c(163, 173, 173, 179, 187, 152, 168, 165, 160, 157, 155, 183)

# Scatter plot
plot(height_age10, height_age16, xlab = "Height at Age 10 (cm)", ylab = "Height at Age 16 (cm)",
     main = "Scatter Plot of Heights", pch = 19, col = "blue")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-aef6f1c4d345> in <cell line: 2>()
#       1 # Data
# ----> 2 height_age10 <- c(132, 140, 137, 150, 155, 127, 147, 135, 135, 124, 127, 145)
#       3 height_age16 <- c(163, 173, 173, 179, 187, 152, 168, 165, 160, 157, 155, 183)
#       4
#       5 # Scatter plot
#
# NameError: name 'height_age10' is not defined
